# %%
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

#X, _ = make_blobs(n_samples=10, centers=3, n_features=4)

#df = pd.DataFrame(X, columns=['Feat_1', 'Feat_2', 'Feat_3', 'Feat_4'])



#y = kmeans.fit_predict(df[['Feat_1', 'Feat_2', 'Feat_3', 'Feat_4']])

#df['Cluster'] = y

#print(df.head())

# %%
df = pd.read_csv("dataset_ventas_segmentacion.csv")

# %%
kmeans = KMeans(n_clusters=3, algorithm='elkan')

# %%
clusters = kmeans.fit_predict(df[['Total']])

# %%
df['Cluster'] = clusters

# %%
df
# Out:
#       ULT_SUST_DEF  TALLA_INI_MIN  TALLA_FIN_MAX  MAR_CVE_N        MARCA  \
# 0            23491           25.0           30.5       1546      DOBLE L
# 1             1560           25.0           32.0        230  MARCO DELLI
# 2            59826           22.0           27.0        870        FLEXI
# 3            59828           22.0           27.0        870        FLEXI
# 4            63526           22.0           33.0       3248    NIABBAL´S
# ...            ...            ...            ...        ...          ...
# 2254        872356           21.0           28.0       1042     MILAGROS
# 2255        872354           21.0           28.0       1042     MILAGROS
# 2256        872360           21.0           28.0       1042     MILAGROS
# 2257        872358           21.0           28.0       1042     MILAGROS
# 2258        872364           21.0           28.0       1042     MILAGROS
#
#      MODELO  COL_CVE_N    COLOR CORRIDAS  DIV_CVE_N  ... SEC_CVE_N    SECCION  \
# ...

# %%
plt.scatter(df["Total"], df["Total"], c=clusters, s=100)
